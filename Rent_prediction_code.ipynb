# %% [markdown]
# <a href="https://colab.research.google.com/github/MeghanaAkkineni/MeghanaAkkineni/blob/main/Rent_prediction_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sms

# %%
dt = pd.read_csv('/content/House_Rent_Dataset.csv')

# %%
dt
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
dt.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
dt['Point of Contact'].unique()
# Out:
# array(['Contact Owner', 'Contact Agent', 'Contact Builder'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
dt['Point of Contact'] = l.fit_transform(dt['Point of Contact'])

# %%
dt['Point of Contact'].unique()
# Out:
# array([2, 0, 1])

# %%
dt
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = dt.drop(['Point of Contact'],axis=1)
y = dt['Point of Contact']

# %%
x
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y, test_size=0.25)

# %%
xtest
# Out:
#        Posted On  BHK   Rent  Size         Floor    Area Type  \
# 2182  2022-06-16    1   6500   400    2 out of 2  Carpet Area
# 4130  2022-06-22    1   7500   500    1 out of 2   Super Area
# 2309  2022-05-27    1  14000   435    3 out of 5  Carpet Area
# 4083  2022-06-25    3  35000  1565    1 out of 6  Carpet Area
# 2785  2022-04-29    3  25000  1000    1 out of 4   Super Area
# ...          ...  ...    ...   ...           ...          ...
# 2826  2022-05-14    3  60000  1600    3 out of 4   Super Area
# 3947  2022-07-05    2  13000  1200    2 out of 5   Super Area
# 608   2022-06-27    3  20000   737  13 out of 15  Carpet Area
# 2398  2022-04-30    1  20000   250    1 out of 1  Carpet Area
# 3906  2022-06-27    2  11000   100    2 out of 3   Super Area
#
#                      Area Locality       City Furnishing Status  \
# 2182                    whitefield  Bangalore    Semi-Furnished
# 4130             Saroornagar, NH 9  Hyderabad       Unfurnished
# ...

# %%
sms.pairplot(dt, hue='Point of Contact')

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-12b6a511cd29> in <cell line: 0>()
# ----> 1 lr.fit(xtrain,ytrain)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1220             _dtype = [np.float64, np.float32]
#    1221
# -> 1222         X, y = validate_data(
#    1223             self,
#    1224             X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
# ...

# %%
dt['Posted On'].unique()
# Out:
# array(['2022-05-18', '2022-05-13', '2022-05-16', '2022-07-04',
#        '2022-05-09', '2022-04-29', '2022-06-21', '2022-06-07',
#        '2022-06-20', '2022-05-23', '2022-05-14', '2022-05-05',
#        '2022-06-01', '2022-05-17', '2022-06-09', '2022-07-02',
#        '2022-06-14', '2022-06-15', '2022-05-28', '2022-05-22',
#        '2022-06-18', '2022-06-25', '2022-06-22', '2022-05-21',
#        '2022-06-26', '2022-06-16', '2022-06-29', '2022-05-10',
#        '2022-05-12', '2022-06-03', '2022-05-31', '2022-06-10',
#        '2022-06-24', '2022-04-30', '2022-05-27', '2022-06-06',
#        '2022-05-20', '2022-05-26', '2022-07-03', '2022-04-23',
#        '2022-06-19', '2022-07-06', '2022-06-04', '2022-05-30',
#        '2022-06-08', '2022-05-03', '2022-05-07', '2022-06-27',
#        '2022-05-15', '2022-04-28', '2022-06-28', '2022-06-23',
#        '2022-06-13', '2022-05-04', '2022-04-25', '2022-05-06',
#        '2022-06-30', '2022-07-01', '2022-06-17', '2022-06-11',
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
dt['Posted On'] = l.fit_transform(dt['Posted On'])

# %%
dt['Posted On'].unique()
# Out:
# array([26, 21, 24, 73, 17,  7, 60, 46, 59, 31, 22, 13, 40, 25, 48, 71, 53,
#        54, 36, 30, 57, 64, 61, 29, 65, 55, 68, 18, 20, 42, 39, 49, 63,  8,
#        35, 45, 28, 34, 72,  1, 58, 75, 43, 38, 47, 11, 15, 66, 23,  6, 67,
#        62, 52, 12,  3, 14, 69, 70, 56, 50, 19, 51, 44, 33, 32, 27,  2,  5,
#        16,  4, 41, 37, 76, 77, 78, 74,  9,  0, 10, 79, 80])

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   int64
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   int64
# dtypes: int64(6), object(6)
# memory usage: 445.1+ KB

# %%
dt['Floor'].unique()
# Out:
# array(['Ground out of 2', '1 out of 3', '1 out of 2', 'Ground out of 1',
#        'Ground out of 4', '1 out of 4', '1 out of 1', 'Ground out of 3',
#        '2 out of 3', '4 out of 5', '2 out of 2', '2 out of 5',
#        '4 out of 14', '3 out of 3', '5 out of 5', '4 out of 4',
#        '7 out of 8', '2 out of 4', '3 out of 4', '1 out of 5',
#        '8 out of 5', 'Ground out of 6', '2 out of 1',
#        'Upper Basement out of 4', 'Ground out of 5', '3 out of 5',
#        '11 out of 19', '5 out of 10', '11 out of 14',
#        'Lower Basement out of 2', '2 out of 7', '4 out of 10',
#        '7 out of 10', '2 out of 13', '6 out of 7', '4 out of 7',
#        '14 out of 14', '43 out of 78', '2 out of 8', '13 out of 18',
#        '5 out of 12', '18 out of 24', '3 out of 7', '17 out of 31',
#        '11 out of 21', '7 out of 19', '14 out of 23', '9 out of 20',
#        'Upper Basement out of 9', '19 out of 24', '3 out of 21',
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
dt['Floor'] = l.fit_transform(dt['Floor'])

# %%
dt['Floor'].unique()
# Out:
# array([455,  14,  10, 447, 458,  16,   1, 457, 196, 313, 192, 200, 301,
#        267, 347, 312, 398, 198, 270,  17, 419, 460, 184, 475, 459, 271,
#         48, 331,  43, 466, 202, 297, 379, 188, 371, 316,  90, 322, 203,
#         84, 333, 160, 275, 150,  50, 388,  97, 433, 479, 175, 263,  12,
#        421, 357, 314, 469, 374, 288, 350, 335, 103, 349, 435,  65, 246,
#         20, 239, 238, 354, 461,  94,  85, 132,  29, 296, 130,  38, 317,
#         71, 282, 268,  86, 437, 327, 396, 250,  81, 365, 407, 201, 340,
#        256, 152,  24, 415, 428,  96, 169, 430,  78, 237, 384,  28, 471,
#        341, 476, 339, 289, 315, 206,  66, 110, 378, 361, 145, 367, 320,
#        182, 120,  57,  32, 146, 111, 423, 381, 411,  42, 432, 295, 356,
#        406,  49,  33, 468, 392, 298, 153, 391,  93, 355, 403, 262, 397,
#        105, 159, 171,  80, 380,  51, 474,  62, 136,  61,  60, 187, 220,
#        383, 334, 390,  95, 147, 427, 414, 273, 144, 158,  19, 438, 276,
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   int64
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   int64
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   int64
# dtypes: int64(7), object(5)
# memory usage: 445.1+ KB

# %%
dt['Area Type'].unique()
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
dt['Area Type'] = l.fit_transform(dt['Area Type'])
dt['Area Type'].unique()
# Out:
# array([2, 1, 0])

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   int64
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   int64
#  5   Area Type          4746 non-null   int64
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   int64
# dtypes: int64(8), object(4)
# memory usage: 445.1+ KB

# %%
dt['Area Locality'].unique()
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
dt['Area Locality'] = l.fit_transform(dt['Area Locality'])
dt['Area Locality'].unique()
# Out:
# array([ 221, 1527, 1760, ...,  183,  633, 1214])

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   int64
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   int64
#  5   Area Type          4746 non-null   int64
#  6   Area Locality      4746 non-null   int64
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   int64
# dtypes: int64(9), object(3)
# memory usage: 445.1+ KB

# %%
dt['City'].unique()
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
dt['City'] = l.fit_transform(dt['City'])
dt['City'].unique()
# Out:
# array([4, 5, 0, 2, 1, 3])

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   int64
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   int64
#  5   Area Type          4746 non-null   int64
#  6   Area Locality      4746 non-null   int64
#  7   City               4746 non-null   int64
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   int64
# dtypes: int64(10), object(2)
# memory usage: 445.1+ KB

# %%
dt['Furnishing Status'].unique()
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
dt['Furnishing Status'] = l.fit_transform(dt['Furnishing Status'])
dt['Furnishing Status'].unique()
# Out:
# array([2, 1, 0])

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   int64
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   int64
#  5   Area Type          4746 non-null   int64
#  6   Area Locality      4746 non-null   int64
#  7   City               4746 non-null   int64
#  8   Furnishing Status  4746 non-null   int64
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   int64
# dtypes: int64(11), object(1)
# memory usage: 445.1+ KB

# %%
dt['Tenant Preferred'].unique()
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
dt['Tenant Preferred'] = l.fit_transform(dt['Tenant Preferred'])
dt['Tenant Preferred'].unique()
# Out:
# array([1, 0, 2])

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   int64
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   int64
#  5   Area Type          4746 non-null   int64
#  6   Area Locality      4746 non-null   int64
#  7   City               4746 non-null   int64
#  8   Furnishing Status  4746 non-null   int64
#  9   Tenant Preferred   4746 non-null   int64
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   int64
# dtypes: int64(12)
# memory usage: 445.1 KB

# %%
dt.describe()
# Out:
#          Posted On          BHK          Rent         Size        Floor  \
# count  4746.000000  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean     46.753055     2.083860  3.499345e+04   967.490729   229.621787
# std      22.044225     0.832256  7.810641e+04   634.202328   162.798036
# min       0.000000     1.000000  1.200000e+03    10.000000     0.000000
# 25%      28.000000     2.000000  1.000000e+04   550.000000    26.000000
# 50%      49.000000     2.000000  1.600000e+04   850.000000   200.000000
# 75%      67.000000     3.000000  3.300000e+04  1200.000000   371.000000
# max      80.000000     6.000000  3.500000e+06  8000.000000   479.000000
#
#          Area Type  Area Locality         City  Furnishing Status  \
# count  4746.000000    4746.000000  4746.000000        4746.000000
# mean      1.514960    1091.711547     2.457016           1.239149
# std       0.500671     633.195921     1.787188           0.684553
# ...

# %%
dt
# Out:
#       Posted On  BHK   Rent  Size  Floor  Area Type  Area Locality  City  \
# 0            26    2  10000  1100    455          2            221     4
# 1            21    2  20000   800     14          2           1527     4
# 2            24    2  17000  1000     14          2           1760     4
# 3            73    2  10000   800     10          2            526     4
# 4            17    2   7500   850     10          1           1890     4
# ...         ...  ...    ...   ...    ...        ...            ...   ...
# 4741         26    2  15000  1000    271          1            219     3
# 4742         23    3  29000  2000     16          2           1214     3
# 4743         79    3  35000  1750    271          1            724     3
# 4744         75    3  45000  1500    226          1            590     3
# 4745         12    2  15000  1000    313          1           1915     3
#
#       Furnishing Status  Tenant Preferred  Bathroom  Point of Contact
# ...

# %%
x = dt.drop(['Rent'],axis=1)
y = dt['Rent']

# %%
x
# Out:
#       Posted On  BHK  Size  Floor  Area Type  Area Locality  City  \
# 0            26    2  1100    455          2            221     4
# 1            21    2   800     14          2           1527     4
# 2            24    2  1000     14          2           1760     4
# 3            73    2   800     10          2            526     4
# 4            17    2   850     10          1           1890     4
# ...         ...  ...   ...    ...        ...            ...   ...
# 4741         26    2  1000    271          1            219     3
# 4742         23    3  2000     16          2           1214     3
# 4743         79    3  1750    271          1            724     3
# 4744         75    3  1500    226          1            590     3
# 4745         12    2  1000    313          1           1915     3
#
#       Furnishing Status  Tenant Preferred  Bathroom  Point of Contact
# 0                     2                 1         2                 2
# ...

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y, test_size=0.25)

# %%
xtest
# Out:
#       Posted On  BHK  Size  Floor  Area Type  Area Locality  City  \
# 79           20    1   500     10          2           1089     4
# 982          66    1   680    349          2            212     5
# 1948         22    1   400    270          2            740     0
# 4049         14    2   720     14          2            255     3
# 3078         21    1   420      1          1           1195     1
# ...         ...  ...   ...    ...        ...            ...   ...
# 1354         31    1   450    316          2            388     5
# 3453         77    4  4000    445          2           1525     1
# 1127         62    2   850    116          1           1547     5
# 4616         65    3   225    447          1           1605     3
# 308          49    1   450    455          1           1760     4
#
#       Furnishing Status  Tenant Preferred  Bathroom  Point of Contact
# 79                    2                 1         1                 2
# ...

# %%
sms.pairplot(dt, hue='Rent')

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
ypred = lr.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.06318449873631002

# %%
import pickle

# %%
pickle.dump(lr,open('rent.pkl', 'wb'))
